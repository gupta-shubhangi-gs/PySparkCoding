# %% [markdown]
# ## Create Spark Data Frame using Header and Inferring Schema
#
# Use the files in dbfs to create Spark Data Frame using Header and Inferring Schema.
# * The files are under `dbfs:/public/udemy_tech`
# * Preview data using `spark.read.text` to understand characteristics of data.
# * Use appropriate key word arguments and API to create Data Frame for the data in the files under `dbfs:/public/udemy_tech`

# %% [markdown]
# ### Step 1: Preview Files

# %%
# %fs ls /public/udemy_tech
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/public/udemy_tech/part-00000</td><td>part-00000</td><td>1775</td></tr></tbody></table></div>

# %% [markdown]
# ### Step 2: Solution
#
# Develop the required logic in the below using appropriate key word arguments. Also, make sure to log the code snippets used to perform the analysis.

# %% [markdown]
# ### Step 3: Validation
#
# Run below cells to perform the validation.

# %%
display(udemy_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
udemy_data.count() # 21
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 21</div>

# %%
udemy_data.dtypes # Output should be as below

# [('course_id', 'int'),
#  ('course_name', 'string'),
#  ('suitable_for', 'string'),
#  ('enrollment', 'int'),
#  ('stars', 'double'),
#  ('number_of_ratings', 'int')]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [(&#39;course_id&#39;, &#39;int&#39;),
#  (&#39;course_name&#39;, &#39;string&#39;),
#  (&#39;suitable_for&#39;, &#39;string&#39;),
#  (&#39;enrollment&#39;, &#39;int&#39;),
#  (&#39;stars&#39;, &#39;double&#39;),
#  (&#39;number_of_ratings&#39;, &#39;int&#39;)]</div>
