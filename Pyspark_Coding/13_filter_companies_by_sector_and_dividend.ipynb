# %% [markdown]
# ## Filter companies by sector and Dividend
#
# Develop the function which returns companies related to the sector which pay Dividend of greater than or equal to specified value.
# * Output Data Frame should contain data based on the criteria.
# * Output Data Frame should be sorted in descending order by dividend.

# %%
companies = [{'Name': 'Accenture',
  'Sector': 'IT',
  'Price': 222.89,
  'Dividend': 2.33,
  'EarningsPerShare': 7.92},
 {'Name': 'Apple',
  'Sector': 'IT',
  'Price': 155.15,
  'Dividend': 1.57,
  'EarningsPerShare': 9.2},
 {'Name': 'Adobe Systems Inc',
  'Sector': 'IT',
  'Price': 185.16,
  'Dividend': 0.0,
  'EarningsPerShare': 3.39},
 {'Name': 'Alphabet',
  'Sector': 'IT',
  'Price': 1007.71,
  'Dividend': 0.0,
  'EarningsPerShare': 22.27},
 {'Name': 'Bank of America Corp',
  'Sector': 'Finacials',
  'Price': 29.74,
  'Dividend': 1.53,
  'EarningsPerShare': 1.55},
 {'Name': 'Biogen Inc',
  'Sector': 'Health Care',
  'Price': 311.79,
  'Dividend': 0.0,
  'EarningsPerShare': 11.94},
 {'Name': 'Campbell Soup',
  'Sector': 'Consumer Staples',
  'Price': 44.83,
  'Dividend': 3.12,
  'EarningsPerShare': 2.89},
 {'Name': 'Dr Pepper Snapple Group',
  'Sector': 'Consumer Staples',
  'Price': 116.93,
  'Dividend': 1.96,
  'EarningsPerShare': 4.54},
 {'Name': 'ebay Inc',
  'Sector': 'IT',
  'Price': 41.02,
  'Dividend': 0.0,
  'EarningsPerShare': -1.07},
 {'Name': 'FedEx Corporation',
  'Sector': 'Industrials',
  'Price': 239.27,
  'Dividend': 0.79,
  'EarningsPerShare': 11.07},
 {'Name': 'Ford Motors',
  'Sector': 'Consumer Products',
  'Price': 10.43,
  'Dividend': 6.78,
  'EarningsPerShare': 1.9},
 {'Name': 'General Motors',
  'Sector': 'Consumer Products',
  'Price': 40.75,
  'Dividend': 3.58,
  'EarningsPerShare': 6.0},
 {'Name': 'Harley-Davidson',
  'Sector': 'Consumer Products',
  'Price': 47.54,
  'Dividend': 3.02,
  'EarningsPerShare': 2.98},
 {'Name': 'Hewlett Packard Enterprise',
  'Sector': 'IT',
  'Price': 15.04,
  'Dividend': 1.92,
  'EarningsPerShare': 0.21},
 {'Name': 'Intel Corp',
  'Sector': 'IT',
  'Price': 42.75,
  'Dividend': 2.65,
  'EarningsPerShare': 1.98},
 {'Name': 'JP Morgan',
  'Sector': 'Finacials',
  'Price': 107.88,
  'Dividend': 1.98,
  'EarningsPerShare': 6.3},
 {'Name': 'Johnson & Johnson',
  'Sector': 'IT',
  'Price': 126.36,
  'Dividend': 2.55,
  'EarningsPerShare': 0.39},
 {'Name': 'Microsoft Corp',
  'Sector': 'IT',
  'Price': 85.01,
  'Dividend': 1.87,
  'EarningsPerShare': 2.97},
 {'Name': 'Netflix Inc',
  'Sector': 'IT',
  'Price': 250.01,
  'Dividend': 0.0,
  'EarningsPerShare': 1.25},
 {'Name': 'Nike',
  'Sector': 'Consumer Products',
  'Price': 62.49,
  'Dividend': 1.21,
  'EarningsPerShare': 2.51}]

companies_df = spark.createDataFrame(companies)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 1: Preview the data
#
# Let us first preview the data.

# %%
display(companies_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Dividend</th><th>EarningsPerShare</th><th>Name</th><th>Price</th><th>Sector</th></tr></thead><tbody><tr><td>2.33</td><td>7.92</td><td>Accenture</td><td>222.89</td><td>IT</td></tr><tr><td>1.57</td><td>9.2</td><td>Apple</td><td>155.15</td><td>IT</td></tr><tr><td>0.0</td><td>3.39</td><td>Adobe Systems Inc</td><td>185.16</td><td>IT</td></tr><tr><td>0.0</td><td>22.27</td><td>Alphabet</td><td>1007.71</td><td>IT</td></tr><tr><td>1.53</td><td>1.55</td><td>Bank of America Corp</td><td>29.74</td><td>Finacials</td></tr><tr><td>0.0</td><td>11.94</td><td>Biogen Inc</td><td>311.79</td><td>Health Care</td></tr><tr><td>3.12</td><td>2.89</td><td>Campbell Soup</td><td>44.83</td><td>Consumer Staples</td></tr><tr><td>1.96</td><td>4.54</td><td>Dr Pepper Snapple Group</td><td>116.93</td><td>Consumer Staples</td></tr><tr><td>0.0</td><td>-1.07</td><td>ebay Inc</td><td>41.02</td><td>IT</td></tr><tr><td>0.79</td><td>11.07</td><td>FedEx Corporation</td><td>239.27</td><td>Industrials</td></tr><tr><td>6.78</td><td>1.9</td><td>Ford Motors</td><td>10.43</td><td>Consumer Products</td></tr><tr><td>3.58</td><td>6.0</td><td>General Motors</td><td>40.75</td><td>Consumer Products</td></tr><tr><td>3.02</td><td>2.98</td><td>Harley-Davidson</td><td>47.54</td><td>Consumer Products</td></tr><tr><td>1.92</td><td>0.21</td><td>Hewlett Packard Enterprise</td><td>15.04</td><td>IT</td></tr><tr><td>2.65</td><td>1.98</td><td>Intel Corp</td><td>42.75</td><td>IT</td></tr><tr><td>1.98</td><td>6.3</td><td>JP Morgan</td><td>107.88</td><td>Finacials</td></tr><tr><td>2.55</td><td>0.39</td><td>Johnson & Johnson</td><td>126.36</td><td>IT</td></tr><tr><td>1.87</td><td>2.97</td><td>Microsoft Corp</td><td>85.01</td><td>IT</td></tr><tr><td>0.0</td><td>1.25</td><td>Netflix Inc</td><td>250.01</td><td>IT</td></tr><tr><td>1.21</td><td>2.51</td><td>Nike</td><td>62.49</td><td>Consumer Products</td></tr></tbody></table></div>

# %%
companies_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: 20</div>

# %% [markdown]
# ### Step 2: Provide the solution
#
# Now come up with the solution by developing the required logic. Once the function is developed, go to the next step to take care of the validation.

# %%
def get_companies_by_sector_and_dividend(companies_df, sector, dividend):
    #Your code should go here
    return companies_by_sector
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 3: Validate the function
#
# Let us validate the function by running below cells. Here is the desired output.
#
# ```
# [{'Dividend': 2.65,
#   'EarningsPerShare': 1.98,
#   'Name': 'Intel Corp',
#   'Price': 42.75,
#   'Sector': 'IT'},
#  {'Dividend': 2.55,
#   'EarningsPerShare': 0.39,
#   'Name': 'Johnson & Johnson',
#   'Price': 126.36,
#   'Sector': 'IT'},
#  {'Dividend': 2.33,
#   'EarningsPerShare': 7.92,
#   'Name': 'Accenture',
#   'Price': 222.89,
#   'Sector': 'IT'},
#  {'Dividend': 1.92,
#   'EarningsPerShare': 0.21,
#   'Name': 'Hewlett Packard Enterprise',
#   'Price': 15.04,
#   'Sector': 'IT'},
#  {'Dividend': 1.87,
#   'EarningsPerShare': 2.97,
#   'Name': 'Microsoft Corp',
#   'Price': 85.01,
#   'Sector': 'IT'},
#  {'Dividend': 1.57,
#   'EarningsPerShare': 9.2,
#   'Name': 'Apple',
#   'Price': 155.15,
#   'Sector': 'IT'}]
# ```

# %%
companies_by_sector_and_dividend = get_companies_by_sector_and_dividend(companies_df, 'IT', 1.5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(companies_by_sector_and_dividend)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Dividend</th><th>EarningsPerShare</th><th>Name</th><th>Price</th><th>Sector</th></tr></thead><tbody><tr><td>2.65</td><td>1.98</td><td>Intel Corp</td><td>42.75</td><td>IT</td></tr><tr><td>2.55</td><td>0.39</td><td>Johnson & Johnson</td><td>126.36</td><td>IT</td></tr><tr><td>2.33</td><td>7.92</td><td>Accenture</td><td>222.89</td><td>IT</td></tr><tr><td>1.92</td><td>0.21</td><td>Hewlett Packard Enterprise</td><td>15.04</td><td>IT</td></tr><tr><td>1.87</td><td>2.97</td><td>Microsoft Corp</td><td>85.01</td><td>IT</td></tr><tr><td>1.57</td><td>9.2</td><td>Apple</td><td>155.15</td><td>IT</td></tr></tbody></table></div>

# %%
companies_by_sector_and_dividend.count() # 6
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 6</div>

# %%
companies_by_sector_and_dividend.toPandas().to_dict(orient='records')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [{&#39;Dividend&#39;: 2.65,
#   &#39;EarningsPerShare&#39;: 1.98,
#   &#39;Name&#39;: &#39;Intel Corp&#39;,
#   &#39;Price&#39;: 42.75,
#   &#39;Sector&#39;: &#39;IT&#39;},
#  {&#39;Dividend&#39;: 2.55,
#   &#39;EarningsPerShare&#39;: 0.39,
#   &#39;Name&#39;: &#39;Johnson &amp; Johnson&#39;,
#   &#39;Price&#39;: 126.36,
#   &#39;Sector&#39;: &#39;IT&#39;},
#  {&#39;Dividend&#39;: 2.33,
#   &#39;EarningsPerShare&#39;: 7.92,
#   &#39;Name&#39;: &#39;Accenture&#39;,
#   &#39;Price&#39;: 222.89,
#   &#39;Sector&#39;: &#39;IT&#39;},
#  {&#39;Dividend&#39;: 1.92,
#   &#39;EarningsPerShare&#39;: 0.21,
#   &#39;Name&#39;: &#39;Hewlett Packard Enterprise&#39;,
#   &#39;Price&#39;: 15.04,
#   &#39;Sector&#39;: &#39;IT&#39;},
#  {&#39;Dividend&#39;: 1.87,
#   &#39;EarningsPerShare&#39;: 2.97,
#   &#39;Name&#39;: &#39;Microsoft Corp&#39;,
#   &#39;Price&#39;: 85.01,
#   &#39;Sector&#39;: &#39;IT&#39;},
#  {&#39;Dividend&#39;: 1.57,
#   &#39;EarningsPerShare&#39;: 9.2,
#   &#39;Name&#39;: &#39;Apple&#39;,
#   &#39;Price&#39;: 155.15,
#   &#39;Sector&#39;: &#39;IT&#39;}]</div>

# %% [markdown]
# You can check by entering another sector name and you should get the desired output related to that.
