# %% [markdown]
# ## Get unique programming languages
#
# Develop a function which takes a delimited string as input and returns unique values ignoring the case.
# * We have a data frame with single column and single row. The only value in the Data Frame is nothing but a string of programming languages which are delimited by `,`.
# * However the programming languages might be in mixed case. Also some of the programming languages have spaces in the beginning or the end.
# * We need to ignore spaces and also ignore the case to get unique list of programming languages.
# * Output should all be lower case, without leading or trailing spaces. The data type of the output should be `list`. Data should be sorted in ascending order.

# %%
programming_languages = [('Python, Java , java,python, Scala, java script, python, Go, scala,java, Ruby, go, ruby, Java Script', )]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.createDataFrame(programming_languages, schema='langs STRING')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 1: Preview the data
# * Let us first preview the data.

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>langs</th></tr></thead><tbody><tr><td>Python, Java , java,python, Scala, java script, python, Go, scala,java, Ruby, go, ruby, Java Script</td></tr></tbody></table></div>

# %%
type(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: pyspark.sql.dataframe.DataFrame</div>

# %% [markdown]
# ### Step 2: Provide the solution
# Now come up with the solution by developing the required logic. Once the function is developed, go to the next step to take care of the validation.

# %%
from pyspark.sql.functions import explode, split, trim, lower
def get_unique_programming_languages(programming_languages):
    # Your solution should go here
    unique_programming_languages = programming_languages. \
        select(explode(split('langs', ',')).alias('lang')). \
        select(lower(trim('lang')).alias('lang')). \
        distinct(). \
        orderBy('lang')
    return unique_programming_languages
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 3: Validate the function
#
# Here is the expected output.
#
# ```python
# [{'lang': 'go'},
#  {'lang': 'java'},
#  {'lang': 'java script'},
#  {'lang': 'python'},
#  {'lang': 'ruby'},
#  {'lang': 'scala'}]
# ```

# %%
unique_programming_languages = get_unique_programming_languages(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(unique_programming_languages)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>lang</th></tr></thead><tbody><tr><td>go</td></tr><tr><td>java</td></tr><tr><td>java script</td></tr><tr><td>python</td></tr><tr><td>ruby</td></tr><tr><td>scala</td></tr></tbody></table></div>

# %%
unique_programming_languages.count() # 6
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: 6</div>

# %%
unique_programming_languages.toPandas().to_dict(orient='records')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [{&#39;lang&#39;: &#39;go&#39;},
#  {&#39;lang&#39;: &#39;java&#39;},
#  {&#39;lang&#39;: &#39;java script&#39;},
#  {&#39;lang&#39;: &#39;python&#39;},
#  {&#39;lang&#39;: &#39;ruby&#39;},
#  {&#39;lang&#39;: &#39;scala&#39;}]</div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
