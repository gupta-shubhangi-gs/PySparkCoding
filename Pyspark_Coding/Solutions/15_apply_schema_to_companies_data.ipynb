# %% [markdown]
# ## Apply Schema to Companies Data
#
# Develop a function which applies schema on top of data. The function shall take 2 arguments - data and attributes.
# * Data should be passed in the form list of comma separated strings.
# * Attributes should be passed in the form of a comma separated string.
# * The function should return list of dicts. Refer to desired output.
# * Make sure the numeric types in the dict are of type float.
#
# **Hint: This scanerio is to be solved by using zip() function**

# %%
fields = 'Name,Sector,Price,Dividend,EarningsPerShare'
# Name and Sector are of type strings
# Price, Dividend and EarningsPerShare are of typd Float or Double
# Using Fields above and data types build StructType
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
companies = [
    ('Accenture', 'IT', 222.89, 2.33, 7.92),
    ('Apple', 'IT', 155.15, 1.57, 9.2),
    ('Adobe Systems Inc', 'IT', 185.16, 0.0, 3.39),
    ('Alphabet', 'IT', 1007.71, 0.0, 22.27),
    ('ebay Inc', 'IT', 41.02, 0.0, -1.07),
    ('Hewlett Packard Enterprise', 'IT', 15.04, 1.92, 0.21),
    ('Intel Corp', 'IT', 42.75, 2.65, 1.98),
    ('Microsoft Corp', 'IT', 85.01, 1.87, 2.97),
    ('Netflix Inc', 'IT', 250.01, 0.0, 1.25)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 1: Preview the Data
# Let us preview the data.

# %%
companies
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [(&#39;Accenture&#39;, &#39;IT&#39;, 222.89, 2.33, 7.92),
#  (&#39;Apple&#39;, &#39;IT&#39;, 155.15, 1.57, 9.2),
#  (&#39;Adobe Systems Inc&#39;, &#39;IT&#39;, 185.16, 0.0, 3.39),
#  (&#39;Alphabet&#39;, &#39;IT&#39;, 1007.71, 0.0, 22.27),
#  (&#39;ebay Inc&#39;, &#39;IT&#39;, 41.02, 0.0, -1.07),
#  (&#39;Hewlett Packard Enterprise&#39;, &#39;IT&#39;, 15.04, 1.92, 0.21),
#  (&#39;Intel Corp&#39;, &#39;IT&#39;, 42.75, 2.65, 1.98),
#  (&#39;Microsoft Corp&#39;, &#39;IT&#39;, 85.01, 1.87, 2.97),
#  (&#39;Netflix Inc&#39;, &#39;IT&#39;, 250.01, 0.0, 1.25)]</div>

# %%
type(companies)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: list</div>

# %%
companies[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: (&#39;Accenture&#39;, &#39;IT&#39;, 222.89, 2.33, 7.92)</div>

# %%
type(companies[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: tuple</div>

# %% [markdown]
# ### Step 2: Provide the Solution
# Provide the solution below.

# %%
# Create Data Frame by applying schema using StructType

from pyspark.sql.types import StructType, StructField, DoubleType, StringType
companies_schema = StructType([
    StructField('Name', StringType()),
    StructField('Sector', StringType()),
    StructField('Price', DoubleType()),
    StructField('Dividend', DoubleType()),
    StructField('EarningsPerShare', DoubleType())
])

companies_with_attrs = spark.createDataFrame(companies, schema=companies_schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 3: Validate the function
# Let us validate the function by running the below cells.
#
# Here is the desired output
# ```python
# [{'Name': 'Accenture',
#   'Sector': 'IT',
#   'Price': 222.89,
#   'Dividend': 2.33,
#   'EarningsPerShare': 7.92},
#  {'Name': 'Apple',
#   'Sector': 'IT',
#   'Price': 155.15,
#   'Dividend': 1.57,
#   'EarningsPerShare': 9.2},
#  {'Name': 'Adobe Systems Inc',
#   'Sector': 'IT',
#   'Price': 185.16,
#   'Dividend': 0.0,
#   'EarningsPerShare': 3.39},
#  {'Name': 'Alphabet',
#   'Sector': 'IT',
#   'Price': 1007.71,
#   'Dividend': 0.0,
#   'EarningsPerShare': 22.27},
#  {'Name': 'ebay Inc',
#   'Sector': 'IT',
#   'Price': 41.02,
#   'Dividend': 0.0,
#   'EarningsPerShare': -1.07},
#  {'Name': 'Hewlett Packard Enterprise',
#   'Sector': 'IT',
#   'Price': 15.04,
#   'Dividend': 1.92,
#   'EarningsPerShare': 0.21},
#  {'Name': 'Intel Corp',
#   'Sector': 'IT',
#   'Price': 42.75,
#   'Dividend': 2.65,
#   'EarningsPerShare': 1.98},
#  {'Name': 'Microsoft Corp',
#   'Sector': 'IT',
#   'Price': 85.01,
#   'Dividend': 1.87,
#   'EarningsPerShare': 2.97},
#  {'Name': 'Netflix Inc',
#   'Sector': 'IT',
#   'Price': 250.01,
#   'Dividend': 0.0,
#   'EarningsPerShare': 1.25}]
# ```

# %%
display(companies_with_attrs)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Sector</th><th>Price</th><th>Dividend</th><th>EarningsPerShare</th></tr></thead><tbody><tr><td>Accenture</td><td>IT</td><td>222.89</td><td>2.33</td><td>7.92</td></tr><tr><td>Apple</td><td>IT</td><td>155.15</td><td>1.57</td><td>9.2</td></tr><tr><td>Adobe Systems Inc</td><td>IT</td><td>185.16</td><td>0.0</td><td>3.39</td></tr><tr><td>Alphabet</td><td>IT</td><td>1007.71</td><td>0.0</td><td>22.27</td></tr><tr><td>ebay Inc</td><td>IT</td><td>41.02</td><td>0.0</td><td>-1.07</td></tr><tr><td>Hewlett Packard Enterprise</td><td>IT</td><td>15.04</td><td>1.92</td><td>0.21</td></tr><tr><td>Intel Corp</td><td>IT</td><td>42.75</td><td>2.65</td><td>1.98</td></tr><tr><td>Microsoft Corp</td><td>IT</td><td>85.01</td><td>1.87</td><td>2.97</td></tr><tr><td>Netflix Inc</td><td>IT</td><td>250.01</td><td>0.0</td><td>1.25</td></tr></tbody></table></div>

# %%
companies_with_attrs.count() # 9
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: 9</div>

# %%
companies_with_attrs.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Name: string (nullable = true)
# -- Sector: string (nullable = true)
# -- Price: double (nullable = true)
# -- Dividend: double (nullable = true)
# -- EarningsPerShare: double (nullable = true)
#
# </div>

# %%
""" # Here is the desired output
[('Name', 'string'),
 ('Sector', 'string'),
 ('Price', 'double'),
 ('Dividend', 'double'),
 ('EarningsPerShare', 'double')]
"""

companies_with_attrs.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [(&#39;Name&#39;, &#39;string&#39;),
#  (&#39;Sector&#39;, &#39;string&#39;),
#  (&#39;Price&#39;, &#39;double&#39;),
#  (&#39;Dividend&#39;, &#39;double&#39;),
#  (&#39;EarningsPerShare&#39;, &#39;double&#39;)]</div>

# %%
# Solution with schema as string

companies_schema = '''
    Name STRING,
    Sector STRING,
    Price DOUBLE,
    Dividend DOUBLE,
    EarningsPerShare DOUBLE
'''

companies_with_attrs = spark.createDataFrame(companies, schema=companies_schema)

display(companies_with_attrs)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Sector</th><th>Price</th><th>Dividend</th><th>EarningsPerShare</th></tr></thead><tbody><tr><td>Accenture</td><td>IT</td><td>222.89</td><td>2.33</td><td>7.92</td></tr><tr><td>Apple</td><td>IT</td><td>155.15</td><td>1.57</td><td>9.2</td></tr><tr><td>Adobe Systems Inc</td><td>IT</td><td>185.16</td><td>0.0</td><td>3.39</td></tr><tr><td>Alphabet</td><td>IT</td><td>1007.71</td><td>0.0</td><td>22.27</td></tr><tr><td>ebay Inc</td><td>IT</td><td>41.02</td><td>0.0</td><td>-1.07</td></tr><tr><td>Hewlett Packard Enterprise</td><td>IT</td><td>15.04</td><td>1.92</td><td>0.21</td></tr><tr><td>Intel Corp</td><td>IT</td><td>42.75</td><td>2.65</td><td>1.98</td></tr><tr><td>Microsoft Corp</td><td>IT</td><td>85.01</td><td>1.87</td><td>2.97</td></tr><tr><td>Netflix Inc</td><td>IT</td><td>250.01</td><td>0.0</td><td>1.25</td></tr></tbody></table></div>
