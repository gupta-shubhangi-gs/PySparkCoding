# %% [markdown]
# ## Get Top Companies by Stock Price
#
# Develop a function to get top companies by stock price. The data should be sorted in descending order by stock price.
# * Get the top stocks by price. The data should be in descending order by the stock price.
# * The function should return a list and each element in the list should be of type dict.

# %%
companies = [{'Name': 'Accenture',
  'Sector': 'IT',
  'Price': 222.89,
  'Dividend': 2.33,
  'EarningsPerShare': 7.92},
 {'Name': 'Apple',
  'Sector': 'IT',
  'Price': 155.15,
  'Dividend': 1.57,
  'EarningsPerShare': 9.2},
 {'Name': 'Adobe Systems Inc',
  'Sector': 'IT',
  'Price': 185.16,
  'Dividend': 0.0,
  'EarningsPerShare': 3.39},
 {'Name': 'Alphabet',
  'Sector': 'IT',
  'Price': 1007.71,
  'Dividend': 0.0,
  'EarningsPerShare': 22.27},
 {'Name': 'Bank of America Corp',
  'Sector': 'Finacials',
  'Price': 29.74,
  'Dividend': 1.53,
  'EarningsPerShare': 1.55},
 {'Name': 'Biogen Inc',
  'Sector': 'Health Care',
  'Price': 311.79,
  'Dividend': 0.0,
  'EarningsPerShare': 11.94},
 {'Name': 'Campbell Soup',
  'Sector': 'Consumer Staples',
  'Price': 44.83,
  'Dividend': 3.12,
  'EarningsPerShare': 2.89},
 {'Name': 'Dr Pepper Snapple Group',
  'Sector': 'Consumer Staples',
  'Price': 116.93,
  'Dividend': 1.96,
  'EarningsPerShare': 4.54},
 {'Name': 'ebay Inc',
  'Sector': 'IT',
  'Price': 41.02,
  'Dividend': 0.0,
  'EarningsPerShare': -1.07},
 {'Name': 'FedEx Corporation',
  'Sector': 'Industrials',
  'Price': 239.27,
  'Dividend': 0.79,
  'EarningsPerShare': 11.07},
 {'Name': 'Ford Motors',
  'Sector': 'Consumer Products',
  'Price': 10.43,
  'Dividend': 6.78,
  'EarningsPerShare': 1.9},
 {'Name': 'General Motors',
  'Sector': 'Consumer Products',
  'Price': 40.75,
  'Dividend': 3.58,
  'EarningsPerShare': 6.0},
 {'Name': 'Harley-Davidson',
  'Sector': 'Consumer Products',
  'Price': 47.54,
  'Dividend': 3.02,
  'EarningsPerShare': 2.98},
 {'Name': 'Hewlett Packard Enterprise',
  'Sector': 'IT',
  'Price': 15.04,
  'Dividend': 1.92,
  'EarningsPerShare': 0.21},
 {'Name': 'Intel Corp',
  'Sector': 'IT',
  'Price': 42.75,
  'Dividend': 2.65,
  'EarningsPerShare': 1.98},
 {'Name': 'JP Morgan',
  'Sector': 'Finacials',
  'Price': 107.88,
  'Dividend': 1.98,
  'EarningsPerShare': 6.3},
 {'Name': 'Johnson & Johnson',
  'Sector': 'IT',
  'Price': 126.36,
  'Dividend': 2.55,
  'EarningsPerShare': 0.39},
 {'Name': 'Microsoft Corp',
  'Sector': 'IT',
  'Price': 85.01,
  'Dividend': 1.87,
  'EarningsPerShare': 2.97},
 {'Name': 'Netflix Inc',
  'Sector': 'IT',
  'Price': 250.01,
  'Dividend': 0.0,
  'EarningsPerShare': 1.25},
 {'Name': 'Nike',
  'Sector': 'Consumer Products',
  'Price': 62.49,
  'Dividend': 1.21,
  'EarningsPerShare': 2.51}]

companies_df = spark.createDataFrame(companies)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 1: Preview the data
#
# Let us first preview the data.

# %%
display(companies_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Dividend</th><th>EarningsPerShare</th><th>Name</th><th>Price</th><th>Sector</th></tr></thead><tbody><tr><td>2.33</td><td>7.92</td><td>Accenture</td><td>222.89</td><td>IT</td></tr><tr><td>1.57</td><td>9.2</td><td>Apple</td><td>155.15</td><td>IT</td></tr><tr><td>0.0</td><td>3.39</td><td>Adobe Systems Inc</td><td>185.16</td><td>IT</td></tr><tr><td>0.0</td><td>22.27</td><td>Alphabet</td><td>1007.71</td><td>IT</td></tr><tr><td>1.53</td><td>1.55</td><td>Bank of America Corp</td><td>29.74</td><td>Finacials</td></tr><tr><td>0.0</td><td>11.94</td><td>Biogen Inc</td><td>311.79</td><td>Health Care</td></tr><tr><td>3.12</td><td>2.89</td><td>Campbell Soup</td><td>44.83</td><td>Consumer Staples</td></tr><tr><td>1.96</td><td>4.54</td><td>Dr Pepper Snapple Group</td><td>116.93</td><td>Consumer Staples</td></tr><tr><td>0.0</td><td>-1.07</td><td>ebay Inc</td><td>41.02</td><td>IT</td></tr><tr><td>0.79</td><td>11.07</td><td>FedEx Corporation</td><td>239.27</td><td>Industrials</td></tr><tr><td>6.78</td><td>1.9</td><td>Ford Motors</td><td>10.43</td><td>Consumer Products</td></tr><tr><td>3.58</td><td>6.0</td><td>General Motors</td><td>40.75</td><td>Consumer Products</td></tr><tr><td>3.02</td><td>2.98</td><td>Harley-Davidson</td><td>47.54</td><td>Consumer Products</td></tr><tr><td>1.92</td><td>0.21</td><td>Hewlett Packard Enterprise</td><td>15.04</td><td>IT</td></tr><tr><td>2.65</td><td>1.98</td><td>Intel Corp</td><td>42.75</td><td>IT</td></tr><tr><td>1.98</td><td>6.3</td><td>JP Morgan</td><td>107.88</td><td>Finacials</td></tr><tr><td>2.55</td><td>0.39</td><td>Johnson & Johnson</td><td>126.36</td><td>IT</td></tr><tr><td>1.87</td><td>2.97</td><td>Microsoft Corp</td><td>85.01</td><td>IT</td></tr><tr><td>0.0</td><td>1.25</td><td>Netflix Inc</td><td>250.01</td><td>IT</td></tr><tr><td>1.21</td><td>2.51</td><td>Nike</td><td>62.49</td><td>Consumer Products</td></tr></tbody></table></div>

# %%
companies_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: 20</div>

# %% [markdown]
# ### Step 2: Provide the solution
#
# Now come up with the solution by developing the required logic. Once the function is developed, go to the next step to take care of the validation.

# %%
from pyspark.sql.functions import col

def get_top_companies_by_stock_price(companies_df, top_n):
    # Your code should go here
    top_companies_by_stock_price = companies_df. \
        orderBy(col('Price').desc()). \
        take(top_n)
    return top_companies_by_stock_price
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 3: Validate the function
#
# Let us validate the function by running below cells.
# * Here is the expected output.
#
# ```python
# [Row(Dividend=0.0, EarningsPerShare=22.27, Name='Alphabet', Price=1007.71, Sector='IT'),
#  Row(Dividend=0.0, EarningsPerShare=11.94, Name='Biogen Inc', Price=311.79, Sector='Health Care'),
#  Row(Dividend=0.0, EarningsPerShare=1.25, Name='Netflix Inc', Price=250.01, Sector='IT'),
#  Row(Dividend=0.79, EarningsPerShare=11.07, Name='FedEx Corporation', Price=239.27, Sector='Industrials'),
#  Row(Dividend=2.33, EarningsPerShare=7.92, Name='Accenture', Price=222.89, Sector='IT')]
# ```

# %%
top_companies_by_stock_price = get_top_companies_by_stock_price(companies_df, 5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
top_companies_by_stock_price
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [Row(Dividend=0.0, EarningsPerShare=22.27, Name=&#39;Alphabet&#39;, Price=1007.71, Sector=&#39;IT&#39;),
#  Row(Dividend=0.0, EarningsPerShare=11.94, Name=&#39;Biogen Inc&#39;, Price=311.79, Sector=&#39;Health Care&#39;),
#  Row(Dividend=0.0, EarningsPerShare=1.25, Name=&#39;Netflix Inc&#39;, Price=250.01, Sector=&#39;IT&#39;),
#  Row(Dividend=0.79, EarningsPerShare=11.07, Name=&#39;FedEx Corporation&#39;, Price=239.27, Sector=&#39;Industrials&#39;),
#  Row(Dividend=2.33, EarningsPerShare=7.92, Name=&#39;Accenture&#39;, Price=222.89, Sector=&#39;IT&#39;)]</div>
