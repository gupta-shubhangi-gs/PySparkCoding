# %% [markdown]
# ## Advanced Sort Courses by Level and Ratings
#
# Develop logic to sort the courses by suitability and number of ratings. As part of this Python Practice Test, we are primarily evaluating the ability to understand lists, dicts, and perform advanced sorting by using custom sorting logic.
# * We will provide course data which will be of type list of dicts.
# * Develop a function which takes the `courses` as input and sort the data by level and then number of ratings.
# * Make sure the data is sorted in custom order by level and then in numerically in descending order by number of ratings. All the Beginner level courses should come first, followed by Intermediate level and then by Advanced level.
# * Here is the data which is in the form of list of dicts.

# %%
courses = [{'course_id': 1,
  'course_name': '2020 Complete Python Bootcamp: From Zero to Hero in Python',
  'suitable_for': 'Beginner',
  'enrollment': 1100093,
  'stars': 4.6,
  'number_of_ratings': 318066},
 {'course_id': 4,
  'course_name': 'Angular - The Complete Guide (2020 Edition)',
  'suitable_for': 'Intermediate',
  'enrollment': 422557,
  'stars': 4.6,
  'number_of_ratings': 129984},
 {'course_id': 12,
  'course_name': 'Automate the Boring Stuff with Python Programming',
  'suitable_for': 'Advanced',
  'enrollment': 692617,
  'stars': 4.6,
  'number_of_ratings': 70508},
 {'course_id': 10,
  'course_name': 'Complete C# Unity Game Developer 2D',
  'suitable_for': 'Advanced',
  'enrollment': 364934,
  'stars': 4.6,
  'number_of_ratings': 78989},
 {'course_id': 5,
  'course_name': 'Java Programming Masterclass for Software Developers',
  'suitable_for': 'Advanced',
  'enrollment': 502572,
  'stars': 4.6,
  'number_of_ratings': 123798},
 {'course_id': 15,
  'course_name': 'Learn Python Programming Masterclass',
  'suitable_for': 'Advanced',
  'enrollment': 240790,
  'stars': 4.5,
  'number_of_ratings': 58677},
 {'course_id': 3,
  'course_name': 'Machine Learning A-Z™: Hands-On Python & R In Data Science',
  'suitable_for': 'Intermediate',
  'enrollment': 692812,
  'stars': 4.5,
  'number_of_ratings': 132228},
 {'course_id': 14,
  'course_name': 'Modern React with Redux [2020 Update]',
  'suitable_for': 'Intermediate',
  'enrollment': 203214,
  'stars': 4.7,
  'number_of_ratings': 60835},
 {'course_id': 8,
  'course_name': 'Python for Data Science and Machine Learning Bootcamp',
  'suitable_for': 'Intermediate',
  'enrollment': 387789,
  'stars': 4.6,
  'number_of_ratings': 87403},
 {'course_id': 6,
  'course_name': 'React - The Complete Guide (incl Hooks, React Router, Redux)',
  'suitable_for': 'Intermediate',
  'enrollment': 304670,
  'stars': 4.6,
  'number_of_ratings': 90964},
 {'course_id': 18,
  'course_name': 'Selenium WebDriver with Java -Basics to Advanced+Frameworks',
  'suitable_for': 'Advanced',
  'enrollment': 148562,
  'stars': 4.6,
  'number_of_ratings': 49947},
 {'course_id': 21,
  'course_name': 'Spring & Hibernate for Beginners (includes Spring Boot)',
  'suitable_for': 'Advanced',
  'enrollment': 177053,
  'stars': 4.6,
  'number_of_ratings': 45329},
 {'course_id': 7,
  'course_name': 'The Complete 2020 Web Development Bootcamp',
  'suitable_for': 'Beginner',
  'enrollment': 270656,
  'stars': 4.7,
  'number_of_ratings': 88098},
 {'course_id': 9,
  'course_name': 'The Complete JavaScript Course 2020: Build Real Projects!',
  'suitable_for': 'Intermediate',
  'enrollment': 347979,
  'stars': 4.6,
  'number_of_ratings': 83521},
 {'course_id': 16,
  'course_name': 'The Complete Node.js Developer Course (3rd Edition)',
  'suitable_for': 'Advanced',
  'enrollment': 202922,
  'stars': 4.7,
  'number_of_ratings': 50885},
 {'course_id': 13,
  'course_name': 'The Complete Web Developer Course 2.0',
  'suitable_for': 'Intermediate',
  'enrollment': 273598,
  'stars': 4.5,
  'number_of_ratings': 63175},
 {'course_id': 11,
  'course_name': 'The Data Science Course 2020: Complete Data Science Bootcamp',
  'suitable_for': 'Beginner',
  'enrollment': 325047,
  'stars': 4.5,
  'number_of_ratings': 76907},
 {'course_id': 20,
  'course_name': 'The Ultimate MySQL Bootcamp: Go from SQL Beginner to Expert',
  'suitable_for': 'Beginner',
  'enrollment': 203366,
  'stars': 4.6,
  'number_of_ratings': 45382},
 {'course_id': 2,
  'course_name': 'The Web Developer Bootcamp',
  'suitable_for': 'Beginner',
  'enrollment': 596726,
  'stars': 4.6,
  'number_of_ratings': 182997},
 {'course_id': 19,
  'course_name': 'Unreal Engine C++ Developer: Learn C++ and Make Video Games',
  'suitable_for': 'Advanced',
  'enrollment': 229005,
  'stars': 4.5,
  'number_of_ratings': 45860},
 {'course_id': 17,
  'course_name': 'iOS 13 & Swift 5 - The Complete iOS App Development Bootcamp',
  'suitable_for': 'Advanced',
  'enrollment': 179598,
  'stars': 4.8,
  'number_of_ratings': 49972}]

courses_df = spark.createDataFrame(courses)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 1: Preview the data
#
# Let us first preview the data.

# %%
display(courses_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>course_id</th><th>course_name</th><th>enrollment</th><th>number_of_ratings</th><th>stars</th><th>suitable_for</th></tr></thead><tbody><tr><td>1</td><td>2020 Complete Python Bootcamp: From Zero to Hero in Python</td><td>1100093</td><td>318066</td><td>4.6</td><td>Beginner</td></tr><tr><td>4</td><td>Angular - The Complete Guide (2020 Edition)</td><td>422557</td><td>129984</td><td>4.6</td><td>Intermediate</td></tr><tr><td>12</td><td>Automate the Boring Stuff with Python Programming</td><td>692617</td><td>70508</td><td>4.6</td><td>Advanced</td></tr><tr><td>10</td><td>Complete C# Unity Game Developer 2D</td><td>364934</td><td>78989</td><td>4.6</td><td>Advanced</td></tr><tr><td>5</td><td>Java Programming Masterclass for Software Developers</td><td>502572</td><td>123798</td><td>4.6</td><td>Advanced</td></tr><tr><td>15</td><td>Learn Python Programming Masterclass</td><td>240790</td><td>58677</td><td>4.5</td><td>Advanced</td></tr><tr><td>3</td><td>Machine Learning A-Z™: Hands-On Python & R In Data Science</td><td>692812</td><td>132228</td><td>4.5</td><td>Intermediate</td></tr><tr><td>14</td><td>Modern React with Redux [2020 Update]</td><td>203214</td><td>60835</td><td>4.7</td><td>Intermediate</td></tr><tr><td>8</td><td>Python for Data Science and Machine Learning Bootcamp</td><td>387789</td><td>87403</td><td>4.6</td><td>Intermediate</td></tr><tr><td>6</td><td>React - The Complete Guide (incl Hooks, React Router, Redux)</td><td>304670</td><td>90964</td><td>4.6</td><td>Intermediate</td></tr><tr><td>18</td><td>Selenium WebDriver with Java -Basics to Advanced+Frameworks</td><td>148562</td><td>49947</td><td>4.6</td><td>Advanced</td></tr><tr><td>21</td><td>Spring & Hibernate for Beginners (includes Spring Boot)</td><td>177053</td><td>45329</td><td>4.6</td><td>Advanced</td></tr><tr><td>7</td><td>The Complete 2020 Web Development Bootcamp</td><td>270656</td><td>88098</td><td>4.7</td><td>Beginner</td></tr><tr><td>9</td><td>The Complete JavaScript Course 2020: Build Real Projects!</td><td>347979</td><td>83521</td><td>4.6</td><td>Intermediate</td></tr><tr><td>16</td><td>The Complete Node.js Developer Course (3rd Edition)</td><td>202922</td><td>50885</td><td>4.7</td><td>Advanced</td></tr><tr><td>13</td><td>The Complete Web Developer Course 2.0</td><td>273598</td><td>63175</td><td>4.5</td><td>Intermediate</td></tr><tr><td>11</td><td>The Data Science Course 2020: Complete Data Science Bootcamp</td><td>325047</td><td>76907</td><td>4.5</td><td>Beginner</td></tr><tr><td>20</td><td>The Ultimate MySQL Bootcamp: Go from SQL Beginner to Expert</td><td>203366</td><td>45382</td><td>4.6</td><td>Beginner</td></tr><tr><td>2</td><td>The Web Developer Bootcamp</td><td>596726</td><td>182997</td><td>4.6</td><td>Beginner</td></tr><tr><td>19</td><td>Unreal Engine C++ Developer: Learn C++ and Make Video Games</td><td>229005</td><td>45860</td><td>4.5</td><td>Advanced</td></tr><tr><td>17</td><td>iOS 13 & Swift 5 - The Complete iOS App Development Bootcamp</td><td>179598</td><td>49972</td><td>4.8</td><td>Advanced</td></tr></tbody></table></div>

# %%
courses_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: 21</div>

# %% [markdown]
# ### Step 2: Provide the solution
#
# Now come up with the solution by developing the required logic. Once the function is developed, go to the next step to take care of the validation.

# %%
# The logic should go here
from pyspark.sql.functions import col, when
def sort_courses_by_level_and_ratings(courses_df):
    courses_sorted = courses_df. \
        orderBy(
            when(courses_df['suitable_for'] == 'Beginner', 0).when(courses_df['suitable_for'] == 'Intermediate', 1).otherwise(2),
            col('number_of_ratings').desc()
        )
    return courses_sorted
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 3: Validate the function
#
# Let us validate the function by running below cells.
# * Here is the expected output.
#
# ```python
# [{'course_id': 1,
#   'course_name': '2020 Complete Python Bootcamp: From Zero to Hero in Python',
#   'suitable_for': 'Beginner',
#   'enrollment': 1100093,
#   'stars': 4.6,
#   'number_of_ratings': 318066},
#  {'course_id': 2,
#   'course_name': 'The Web Developer Bootcamp',
#   'suitable_for': 'Beginner',
#   'enrollment': 596726,
#   'stars': 4.6,
#   'number_of_ratings': 182997},
#  {'course_id': 7,
#   'course_name': 'The Complete 2020 Web Development Bootcamp',
#   'suitable_for': 'Beginner',
#   'enrollment': 270656,
#   'stars': 4.7,
#   'number_of_ratings': 88098},
#  {'course_id': 11,
#   'course_name': 'The Data Science Course 2020: Complete Data Science Bootcamp',
#   'suitable_for': 'Beginner',
#   'enrollment': 325047,
#   'stars': 4.5,
#   'number_of_ratings': 76907},
#  {'course_id': 20,
#   'course_name': 'The Ultimate MySQL Bootcamp: Go from SQL Beginner to Expert',
#   'suitable_for': 'Beginner',
#   'enrollment': 203366,
#   'stars': 4.6,
#   'number_of_ratings': 45382},
#  {'course_id': 3,
#   'course_name': 'Machine Learning A-Z™: Hands-On Python & R In Data Science',
#   'suitable_for': 'Intermediate',
#   'enrollment': 692812,
#   'stars': 4.5,
#   'number_of_ratings': 132228},
#  {'course_id': 4,
#   'course_name': 'Angular - The Complete Guide (2020 Edition)',
#   'suitable_for': 'Intermediate',
#   'enrollment': 422557,
#   'stars': 4.6,
#   'number_of_ratings': 129984},
#  {'course_id': 6,
#   'course_name': 'React - The Complete Guide (incl Hooks, React Router, Redux)',
#   'suitable_for': 'Intermediate',
#   'enrollment': 304670,
#   'stars': 4.6,
#   'number_of_ratings': 90964},
#  {'course_id': 8,
#   'course_name': 'Python for Data Science and Machine Learning Bootcamp',
#   'suitable_for': 'Intermediate',
#   'enrollment': 387789,
#   'stars': 4.6,
#   'number_of_ratings': 87403},
#  {'course_id': 9,
#   'course_name': 'The Complete JavaScript Course 2020: Build Real Projects!',
#   'suitable_for': 'Intermediate',
#   'enrollment': 347979,
#   'stars': 4.6,
#   'number_of_ratings': 83521},
#  {'course_id': 13,
#   'course_name': 'The Complete Web Developer Course 2.0',
#   'suitable_for': 'Intermediate',
#   'enrollment': 273598,
#   'stars': 4.5,
#   'number_of_ratings': 63175},
#  {'course_id': 14,
#   'course_name': 'Modern React with Redux [2020 Update]',
#   'suitable_for': 'Intermediate',
#   'enrollment': 203214,
#   'stars': 4.7,
#   'number_of_ratings': 60835},
#  {'course_id': 5,
#   'course_name': 'Java Programming Masterclass for Software Developers',
#   'suitable_for': 'Advanced',
#   'enrollment': 502572,
#   'stars': 4.6,
#   'number_of_ratings': 123798},
#  {'course_id': 10,
#   'course_name': 'Complete C# Unity Game Developer 2D',
#   'suitable_for': 'Advanced',
#   'enrollment': 364934,
#   'stars': 4.6,
#   'number_of_ratings': 78989},
#  {'course_id': 12,
#   'course_name': 'Automate the Boring Stuff with Python Programming',
#   'suitable_for': 'Advanced',
#   'enrollment': 692617,
#   'stars': 4.6,
#   'number_of_ratings': 70508},
#  {'course_id': 15,
#   'course_name': 'Learn Python Programming Masterclass',
#   'suitable_for': 'Advanced',
#   'enrollment': 240790,
#   'stars': 4.5,
#   'number_of_ratings': 58677},
#  {'course_id': 16,
#   'course_name': 'The Complete Node.js Developer Course (3rd Edition)',
#   'suitable_for': 'Advanced',
#   'enrollment': 202922,
#   'stars': 4.7,
#   'number_of_ratings': 50885},
#  {'course_id': 17,
#   'course_name': 'iOS 13 & Swift 5 - The Complete iOS App Development Bootcamp',
#   'suitable_for': 'Advanced',
#   'enrollment': 179598,
#   'stars': 4.8,
#   'number_of_ratings': 49972},
#  {'course_id': 18,
#   'course_name': 'Selenium WebDriver with Java -Basics to Advanced+Frameworks',
#   'suitable_for': 'Advanced',
#   'enrollment': 148562,
#   'stars': 4.6,
#   'number_of_ratings': 49947},
#  {'course_id': 19,
#   'course_name': 'Unreal Engine C++ Developer: Learn C++ and Make Video Games',
#   'suitable_for': 'Advanced',
#   'enrollment': 229005,
#   'stars': 4.5,
#   'number_of_ratings': 45860},
#  {'course_id': 21,
#   'course_name': 'Spring & Hibernate for Beginners (includes Spring Boot)',
#   'suitable_for': 'Advanced',
#   'enrollment': 177053,
#   'stars': 4.6,
#   'number_of_ratings': 45329}]
# ```

# %%
courses_sorted = sort_courses_by_level_and_ratings(courses_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(courses_sorted)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>course_id</th><th>course_name</th><th>enrollment</th><th>number_of_ratings</th><th>stars</th><th>suitable_for</th></tr></thead><tbody><tr><td>1</td><td>2020 Complete Python Bootcamp: From Zero to Hero in Python</td><td>1100093</td><td>318066</td><td>4.6</td><td>Beginner</td></tr><tr><td>2</td><td>The Web Developer Bootcamp</td><td>596726</td><td>182997</td><td>4.6</td><td>Beginner</td></tr><tr><td>7</td><td>The Complete 2020 Web Development Bootcamp</td><td>270656</td><td>88098</td><td>4.7</td><td>Beginner</td></tr><tr><td>11</td><td>The Data Science Course 2020: Complete Data Science Bootcamp</td><td>325047</td><td>76907</td><td>4.5</td><td>Beginner</td></tr><tr><td>20</td><td>The Ultimate MySQL Bootcamp: Go from SQL Beginner to Expert</td><td>203366</td><td>45382</td><td>4.6</td><td>Beginner</td></tr><tr><td>3</td><td>Machine Learning A-Z™: Hands-On Python & R In Data Science</td><td>692812</td><td>132228</td><td>4.5</td><td>Intermediate</td></tr><tr><td>4</td><td>Angular - The Complete Guide (2020 Edition)</td><td>422557</td><td>129984</td><td>4.6</td><td>Intermediate</td></tr><tr><td>6</td><td>React - The Complete Guide (incl Hooks, React Router, Redux)</td><td>304670</td><td>90964</td><td>4.6</td><td>Intermediate</td></tr><tr><td>8</td><td>Python for Data Science and Machine Learning Bootcamp</td><td>387789</td><td>87403</td><td>4.6</td><td>Intermediate</td></tr><tr><td>9</td><td>The Complete JavaScript Course 2020: Build Real Projects!</td><td>347979</td><td>83521</td><td>4.6</td><td>Intermediate</td></tr><tr><td>13</td><td>The Complete Web Developer Course 2.0</td><td>273598</td><td>63175</td><td>4.5</td><td>Intermediate</td></tr><tr><td>14</td><td>Modern React with Redux [2020 Update]</td><td>203214</td><td>60835</td><td>4.7</td><td>Intermediate</td></tr><tr><td>5</td><td>Java Programming Masterclass for Software Developers</td><td>502572</td><td>123798</td><td>4.6</td><td>Advanced</td></tr><tr><td>10</td><td>Complete C# Unity Game Developer 2D</td><td>364934</td><td>78989</td><td>4.6</td><td>Advanced</td></tr><tr><td>12</td><td>Automate the Boring Stuff with Python Programming</td><td>692617</td><td>70508</td><td>4.6</td><td>Advanced</td></tr><tr><td>15</td><td>Learn Python Programming Masterclass</td><td>240790</td><td>58677</td><td>4.5</td><td>Advanced</td></tr><tr><td>16</td><td>The Complete Node.js Developer Course (3rd Edition)</td><td>202922</td><td>50885</td><td>4.7</td><td>Advanced</td></tr><tr><td>17</td><td>iOS 13 & Swift 5 - The Complete iOS App Development Bootcamp</td><td>179598</td><td>49972</td><td>4.8</td><td>Advanced</td></tr><tr><td>18</td><td>Selenium WebDriver with Java -Basics to Advanced+Frameworks</td><td>148562</td><td>49947</td><td>4.6</td><td>Advanced</td></tr><tr><td>19</td><td>Unreal Engine C++ Developer: Learn C++ and Make Video Games</td><td>229005</td><td>45860</td><td>4.5</td><td>Advanced</td></tr><tr><td>21</td><td>Spring & Hibernate for Beginners (includes Spring Boot)</td><td>177053</td><td>45329</td><td>4.6</td><td>Advanced</td></tr></tbody></table></div>

# %%
courses_sorted.count() # 21
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: 21</div>

# %%
courses_sorted.toPandas().to_dict(orient='records')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [{&#39;course_id&#39;: 1,
#   &#39;course_name&#39;: &#39;2020 Complete Python Bootcamp: From Zero to Hero in Python&#39;,
#   &#39;enrollment&#39;: 1100093,
#   &#39;number_of_ratings&#39;: 318066,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Beginner&#39;},
#  {&#39;course_id&#39;: 2,
#   &#39;course_name&#39;: &#39;The Web Developer Bootcamp&#39;,
#   &#39;enrollment&#39;: 596726,
#   &#39;number_of_ratings&#39;: 182997,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Beginner&#39;},
#  {&#39;course_id&#39;: 7,
#   &#39;course_name&#39;: &#39;The Complete 2020 Web Development Bootcamp&#39;,
#   &#39;enrollment&#39;: 270656,
#   &#39;number_of_ratings&#39;: 88098,
#   &#39;stars&#39;: 4.7,
#   &#39;suitable_for&#39;: &#39;Beginner&#39;},
#  {&#39;course_id&#39;: 11,
#   &#39;course_name&#39;: &#39;The Data Science Course 2020: Complete Data Science Bootcamp&#39;,
#   &#39;enrollment&#39;: 325047,
#   &#39;number_of_ratings&#39;: 76907,
#   &#39;stars&#39;: 4.5,
#   &#39;suitable_for&#39;: &#39;Beginner&#39;},
#  {&#39;course_id&#39;: 20,
#   &#39;course_name&#39;: &#39;The Ultimate MySQL Bootcamp: Go from SQL Beginner to Expert&#39;,
#   &#39;enrollment&#39;: 203366,
#   &#39;number_of_ratings&#39;: 45382,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Beginner&#39;},
#  {&#39;course_id&#39;: 3,
#   &#39;course_name&#39;: &#39;Machine Learning A-Z™: Hands-On Python &amp; R In Data Science&#39;,
#   &#39;enrollment&#39;: 692812,
#   &#39;number_of_ratings&#39;: 132228,
#   &#39;stars&#39;: 4.5,
#   &#39;suitable_for&#39;: &#39;Intermediate&#39;},
#  {&#39;course_id&#39;: 4,
#   &#39;course_name&#39;: &#39;Angular - The Complete Guide (2020 Edition)&#39;,
#   &#39;enrollment&#39;: 422557,
#   &#39;number_of_ratings&#39;: 129984,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Intermediate&#39;},
#  {&#39;course_id&#39;: 6,
#   &#39;course_name&#39;: &#39;React - The Complete Guide (incl Hooks, React Router, Redux)&#39;,
#   &#39;enrollment&#39;: 304670,
#   &#39;number_of_ratings&#39;: 90964,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Intermediate&#39;},
#  {&#39;course_id&#39;: 8,
#   &#39;course_name&#39;: &#39;Python for Data Science and Machine Learning Bootcamp&#39;,
#   &#39;enrollment&#39;: 387789,
#   &#39;number_of_ratings&#39;: 87403,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Intermediate&#39;},
#  {&#39;course_id&#39;: 9,
#   &#39;course_name&#39;: &#39;The Complete JavaScript Course 2020: Build Real Projects!&#39;,
#   &#39;enrollment&#39;: 347979,
#   &#39;number_of_ratings&#39;: 83521,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Intermediate&#39;},
#  {&#39;course_id&#39;: 13,
#   &#39;course_name&#39;: &#39;The Complete Web Developer Course 2.0&#39;,
#   &#39;enrollment&#39;: 273598,
#   &#39;number_of_ratings&#39;: 63175,
#   &#39;stars&#39;: 4.5,
#   &#39;suitable_for&#39;: &#39;Intermediate&#39;},
#  {&#39;course_id&#39;: 14,
#   &#39;course_name&#39;: &#39;Modern React with Redux [2020 Update]&#39;,
#   &#39;enrollment&#39;: 203214,
#   &#39;number_of_ratings&#39;: 60835,
#   &#39;stars&#39;: 4.7,
#   &#39;suitable_for&#39;: &#39;Intermediate&#39;},
#  {&#39;course_id&#39;: 5,
#   &#39;course_name&#39;: &#39;Java Programming Masterclass for Software Developers&#39;,
#   &#39;enrollment&#39;: 502572,
#   &#39;number_of_ratings&#39;: 123798,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Advanced&#39;},
#  {&#39;course_id&#39;: 10,
#   &#39;course_name&#39;: &#39;Complete C# Unity Game Developer 2D&#39;,
#   &#39;enrollment&#39;: 364934,
#   &#39;number_of_ratings&#39;: 78989,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Advanced&#39;},
#  {&#39;course_id&#39;: 12,
#   &#39;course_name&#39;: &#39;Automate the Boring Stuff with Python Programming&#39;,
#   &#39;enrollment&#39;: 692617,
#   &#39;number_of_ratings&#39;: 70508,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Advanced&#39;},
#  {&#39;course_id&#39;: 15,
#   &#39;course_name&#39;: &#39;Learn Python Programming Masterclass&#39;,
#   &#39;enrollment&#39;: 240790,
#   &#39;number_of_ratings&#39;: 58677,
#   &#39;stars&#39;: 4.5,
#   &#39;suitable_for&#39;: &#39;Advanced&#39;},
#  {&#39;course_id&#39;: 16,
#   &#39;course_name&#39;: &#39;The Complete Node.js Developer Course (3rd Edition)&#39;,
#   &#39;enrollment&#39;: 202922,
#   &#39;number_of_ratings&#39;: 50885,
#   &#39;stars&#39;: 4.7,
#   &#39;suitable_for&#39;: &#39;Advanced&#39;},
#  {&#39;course_id&#39;: 17,
#   &#39;course_name&#39;: &#39;iOS 13 &amp; Swift 5 - The Complete iOS App Development Bootcamp&#39;,
#   &#39;enrollment&#39;: 179598,
#   &#39;number_of_ratings&#39;: 49972,
#   &#39;stars&#39;: 4.8,
#   &#39;suitable_for&#39;: &#39;Advanced&#39;},
#  {&#39;course_id&#39;: 18,
#   &#39;course_name&#39;: &#39;Selenium WebDriver with Java -Basics to Advanced+Frameworks&#39;,
#   &#39;enrollment&#39;: 148562,
#   &#39;number_of_ratings&#39;: 49947,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Advanced&#39;},
#  {&#39;course_id&#39;: 19,
#   &#39;course_name&#39;: &#39;Unreal Engine C++ Developer: Learn C++ and Make Video Games&#39;,
#   &#39;enrollment&#39;: 229005,
#   &#39;number_of_ratings&#39;: 45860,
#   &#39;stars&#39;: 4.5,
#   &#39;suitable_for&#39;: &#39;Advanced&#39;},
#  {&#39;course_id&#39;: 21,
#   &#39;course_name&#39;: &#39;Spring &amp; Hibernate for Beginners (includes Spring Boot)&#39;,
#   &#39;enrollment&#39;: 177053,
#   &#39;number_of_ratings&#39;: 45329,
#   &#39;stars&#39;: 4.6,
#   &#39;suitable_for&#39;: &#39;Advanced&#39;}]</div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
