# %% [markdown]
# ## Get Student Total Score
#
# Develop a function to convert get the total score of each student. This is primarily to test the ability to manipulate dicts using first class functions such as map.
# * We will provide list of dicts with student id and scores for different subjects.
# * Develop a function which takes students as input and return students including individual total score.
# * You need to add another element to each of the dicts with key `total_score`.
# * The output should be sorted in descending order by total.
#
# ```{note}
# Hint: You need to define and call named function as part of the map to add `total_score` to each of the dicts in the list.
# ```
#
# **Restrictions: You should not use loops or Pandas to solve this problem. Use first class functions such as `map`.**

# %%
students = [
    {'student_id': 1, 'math_score': 72, 'reading_score': 72, 'writing_score': 74},
    {'student_id': 2, 'math_score': 69, 'reading_score': 90, 'writing_score': 88},
    {'student_id': 3, 'math_score': 90, 'reading_score': 95, 'writing_score': 93},
    {'student_id': 4, 'math_score': 47, 'reading_score': 47, 'writing_score': 44},
    {'student_id': 5, 'math_score': 76, 'reading_score': 78, 'writing_score': 75},
    {'student_id': 6, 'math_score': 71, 'reading_score': 83, 'writing_score': 78}
]

students_df = spark.createDataFrame(students)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 1: Preview the data
#
# Let us first preview the data.

# %%
display(students_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>math_score</th><th>reading_score</th><th>student_id</th><th>writing_score</th></tr></thead><tbody><tr><td>72</td><td>72</td><td>1</td><td>74</td></tr><tr><td>69</td><td>90</td><td>2</td><td>88</td></tr><tr><td>90</td><td>95</td><td>3</td><td>93</td></tr><tr><td>47</td><td>47</td><td>4</td><td>44</td></tr><tr><td>76</td><td>78</td><td>5</td><td>75</td></tr><tr><td>71</td><td>83</td><td>6</td><td>78</td></tr></tbody></table></div>

# %%
students_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: 6</div>

# %% [markdown]
# ### Step 2: Provide the solution
#
# Now come up with the solution by developing the required logic. Once the function is developed, go to the next step to take care of the validation.

# %%
from pyspark.sql.functions import col

def get_students_with_total_scores(students_df):
    ## your code should go here
    ## Make sure to create another function to compute total and update the dict
    students_with_total_scores = students_df. \
        withColumn('total_score', col('math_score') + col('reading_score') + col('writing_score')). \
        orderBy(col('total_score').desc()). \
        select('student_id', 'math_score', 'reading_score', 'writing_score', 'total_score')
    return students_with_total_scores
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 3: Validate the function
#
# Let us validate the function by running below cells.
# * Here is the expected output.
#
# ```python
# [{'student_id': 3,
#   'math_score': 90,
#   'reading_score': 95,
#   'writing_score': 93,
#   'total_score': 278},
#  {'student_id': 2,
#   'math_score': 69,
#   'reading_score': 90,
#   'writing_score': 88,
#   'total_score': 247},
#  {'student_id': 6,
#   'math_score': 71,
#   'reading_score': 83,
#   'writing_score': 78,
#   'total_score': 232},
#  {'student_id': 5,
#   'math_score': 76,
#   'reading_score': 78,
#   'writing_score': 75,
#   'total_score': 229},
#  {'student_id': 1,
#   'math_score': 72,
#   'reading_score': 72,
#   'writing_score': 74,
#   'total_score': 218},
#  {'student_id': 4,
#   'math_score': 47,
#   'reading_score': 47,
#   'writing_score': 44,
#   'total_score': 138}]
# ```

# %%
students_with_total_scores = get_students_with_total_scores(students_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(students_with_total_scores) # 6
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>student_id</th><th>math_score</th><th>reading_score</th><th>writing_score</th><th>total_score</th></tr></thead><tbody><tr><td>3</td><td>90</td><td>95</td><td>93</td><td>278</td></tr><tr><td>2</td><td>69</td><td>90</td><td>88</td><td>247</td></tr><tr><td>6</td><td>71</td><td>83</td><td>78</td><td>232</td></tr><tr><td>5</td><td>76</td><td>78</td><td>75</td><td>229</td></tr><tr><td>1</td><td>72</td><td>72</td><td>74</td><td>218</td></tr><tr><td>4</td><td>47</td><td>47</td><td>44</td><td>138</td></tr></tbody></table></div>

# %%
students_with_total_scores.count() # 6
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 6</div>

# %%
students_with_total_scores.toPandas().to_dict(orient='records')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [{&#39;student_id&#39;: 3,
#   &#39;math_score&#39;: 90,
#   &#39;reading_score&#39;: 95,
#   &#39;writing_score&#39;: 93,
#   &#39;total_score&#39;: 278},
#  {&#39;student_id&#39;: 2,
#   &#39;math_score&#39;: 69,
#   &#39;reading_score&#39;: 90,
#   &#39;writing_score&#39;: 88,
#   &#39;total_score&#39;: 247},
#  {&#39;student_id&#39;: 6,
#   &#39;math_score&#39;: 71,
#   &#39;reading_score&#39;: 83,
#   &#39;writing_score&#39;: 78,
#   &#39;total_score&#39;: 232},
#  {&#39;student_id&#39;: 5,
#   &#39;math_score&#39;: 76,
#   &#39;reading_score&#39;: 78,
#   &#39;writing_score&#39;: 75,
#   &#39;total_score&#39;: 229},
#  {&#39;student_id&#39;: 1,
#   &#39;math_score&#39;: 72,
#   &#39;reading_score&#39;: 72,
#   &#39;writing_score&#39;: 74,
#   &#39;total_score&#39;: 218},
#  {&#39;student_id&#39;: 4,
#   &#39;math_score&#39;: 47,
#   &#39;reading_score&#39;: 47,
#   &#39;writing_score&#39;: 44,
#   &#39;total_score&#39;: 138}]</div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
