# %% [markdown]
# ## Aggregations on Array Type Column in Spark Data Frame
#
# Develop a function to get number of times the color is repeated in arrays in the Data Frame. The logic should check whether the color exists or not.
# * The input data is in the form of Spark Data Frame. Each column in the Data Frame is of type Array.
# * Each Array contain multiple colors.
# * The function should take 2 arguments. The first argument is Spark Data Frame which contain colors. The second argument is the color which you want to check.
# * If the color that is passed as second argument, exists in any of the tuples, then the function should return number of times it is present across all the rows of Arrays.
# * The characters in the second argument might be passed in any case. However, we need to perform case insensitive search.

# %%
colors = [
    (('Red', 'White', 'Yellow'),),
    (('YELLOW', 'Pink', 'red'),),
    (('blue', 'Yellow', 'Lime'),)
]

colors_df = spark.createDataFrame(colors, schema='colors ARRAY<STRING>')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Step 1: Preview the data
# * Let us first preview the data.

# %%
colors_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[colors: array&lt;string&gt;]</div>

# %%
colors_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: 3</div>

# %%
colors_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#               colors|
# +--------------------+
# [Red, White, Yellow]|
#  [YELLOW, Pink, red]|
# [blue, Yellow, Lime]|
# +--------------------+
#
# </div>

# %% [markdown]
# ## Step 2: Provide the solution
# Now come up with the solution by developing the required logic. Once the function is developed, go to the next step to take care of the validation.

# %%
def color_count(colors_df, color):
    # your code should go here
    return cnt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 3: Validate the function
#
# * Here is the expected output.

# %%
color_count(colors_df, 'Red') # 2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: 2</div>

# %%
color_count(colors_df, 'red') # 2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 2</div>

# %%
color_count(colors_df, 'Black') # 0
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: 0</div>

# %%
color_count(colors_df, 'YELLOW') # 3
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: 3</div>
