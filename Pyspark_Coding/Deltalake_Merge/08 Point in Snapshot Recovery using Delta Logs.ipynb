# %%
# %run "./07 Deleting using Merge in Delta Lake"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
# ...

# %%
students_delta
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: &lt;delta.tables.DeltaTable at 0x7fab4193ccd0&gt;</div>

# %%
help(students_delta.history)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on method history in module delta.tables:
#
# history(limit=None) method of delta.tables.DeltaTable instance
#     Get the information of the latest `limit` commits on this table as a Spark DataFrame.
#     The information is in reverse chronological order.
#
#     Example::
#
#         fullHistoryDF = deltaTable.history()    # get the full history of the table
#
#         lastOperationDF = deltaTable.history(1) # get the last operation
#
#     :param limit: Optional, number of latest commits to returns in the history.
#     :return: Table&#39;s commit history. See the online Delta Lake documentation for more details.
# ...

# %%
display(students_delta.history())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
help(students_delta.restoreToVersion)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on method restoreToVersion in module delta.tables:
#
# restoreToVersion(version) method of delta.tables.DeltaTable instance
#     Restore the DeltaTable to an older version of the table specified by version number.
#
#     Example::
#         # to restore the table to version 1
#         io.delta.tables.DeltaTable.restoreToVersion(1)
#
#     :param version: Version at which to clone the source directory. Take the metadata at this
#     version of the table as well.
#     :type version: number
#     .. note:: Evolving
#
# </div>

# %%
students_delta.restoreToVersion(0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: JavaObject id=o800</div>

# %%
students_delta.toDF().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------------------+-----------------+--------------------+--------------+---------------------+--------------------+------+
# student_id|student_first_name|student_last_name|       student_email|student_gender|student_phone_numbers|     student_address|action|
# +----------+------------------+-----------------+--------------------+--------------+---------------------+--------------------+------+
#          3|           Richart|           Zimmer|   rzimmer2@ox.ac.uk|    Non-binary| [3129072019, 2815...|[state -&gt; Florida...|     I|
# ...

# %%
# %fs ls /mnt/itv-github-db/sandbox/students
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls /mnt/itv-github-db/sandbox/students/_delta_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(students_delta.history())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
help(students_delta.restoreToTimestamp)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on method restoreToTimestamp in module delta.tables:
#
# restoreToTimestamp(timestamp) method of delta.tables.DeltaTable instance
#     Restore the DeltaTable to an older version of the table specified by timestamp.
#     Timestamp can be of the format `yyyy-MM-dd` or `yyyy-MM-dd HH:mm:ss`.
#
#     Example::
#         # to restore the table to the version at timestamp of format (yyyy-MM-dd&#39;T&#39;HH:mm:ss)
#         io.delta.tables.DeltaTable.restoreToTimestamp(&#34;2019-01-01&#34;)
#
#     :param timestamp: Timestamp at which to clone the source directory. Take the metadata at
#     this timestamp as well.
# ...

# %%
students_delta.restoreToTimestamp('2021-02-27T00:04:50.000+0000')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: JavaObject id=o896</div>

# %%
students_delta.toDF().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------------------+-----------------+--------------------+--------------+---------------------+--------------------+------+
# student_id|student_first_name|student_last_name|       student_email|student_gender|student_phone_numbers|     student_address|action|
# +----------+------------------+-----------------+--------------------+--------------+---------------------+--------------------+------+
#          3|           Richart|           Zimmer|   rzimmer2@ox.ac.uk|    Non-binary| [3129072019, 2815...|[state -&gt; Florida...|     I|
# ...

# %%
display(students_delta.history())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls /mnt/itv-github-db/sandbox/students
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls /mnt/itv-github-db/sandbox/students/_delta_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
